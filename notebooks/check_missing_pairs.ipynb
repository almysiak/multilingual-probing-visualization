# %%
import pandas as pd
from itertools import product
import os

# %%
LANGS = ('be', 'cs', 'de', 'en', 'es', 'fi', 'fr', 'id', 'lv', 'lt', 'pl', 'ru', 'slk', 'slv', 'uk', 'zh', 'ar', 'bg', 'tr', 'ko', 'hy', 'fa', 'ja', 'ga', 'cy')

# %%
LIMITS = (1000, 2500, 5000, 7500, 10000)

# %%
res_df = pd.read_csv('multilingual-probing-visualization/probingOutputs/all_slavic/all_results.csv')

# %%
res_df['train'] = res_df.train.str[2:-2]
res_df['test'] = res_df.test.str[2:-2]

# %%
res_df.head()
# Out:
#   train test  model  layer  rank    limit  seed  \
# 0    be   be  mBERT      6   128    100.0     0
# 1    be   be  mBERT      6   128   1000.0     0
# 2    be   be  mBERT      6   128  10000.0     0
# 3    be   be  mBERT      6   128   2500.0     0
# 4    be   be  mBERT      6   128   5000.0     0
#
#                                            directory    dspear      uuas
# 0  /home/amysiak/thesis/multilingual-probing-visu...  0.416957  0.397976
# 1  /home/amysiak/thesis/multilingual-probing-visu...  0.711804  0.634634
# 2  /home/amysiak/thesis/multilingual-probing-visu...  0.779117  0.787562
# 3  /home/amysiak/thesis/multilingual-probing-visu...  0.756653  0.720526
# 4  /home/amysiak/thesis/multilingual-probing-visu...  0.770321  0.756249

# %%
missing = set()

# %%
counter = 0
for l1, l2, limit in product(LANGS, LANGS, LIMITS):
    df = res_df[(res_df.test == l1) & (res_df.train == l2) & (res_df.limit == limit)]
    if len(df) < 1:
        print(f"Missing: test {l1}, train {l2}, limit {limit}")
        counter += 1
        missing.add((l1, l2, str(limit)))
# Out:
# Missing: test be, train id, limit 5000
# Missing: test be, train id, limit 7500
# Missing: test be, train id, limit 10000
# Missing: test be, train lt, limit 5000
# Missing: test be, train lt, limit 7500
# Missing: test be, train lt, limit 10000
# Missing: test be, train slk, limit 10000
# Missing: test be, train uk, limit 7500
# Missing: test be, train uk, limit 10000
# Missing: test be, train zh, limit 5000
# Missing: test be, train zh, limit 7500
# Missing: test be, train zh, limit 10000
# Missing: test be, train ar, limit 7500
# Missing: test be, train ar, limit 10000
# Missing: test be, train bg, limit 10000
# Missing: test be, train hy, limit 2500
# Missing: test be, train hy, limit 5000
# Missing: test be, train hy, limit 7500
# Missing: test be, train hy, limit 10000
# Missing: test be, train fa, limit 1000
# Missing: test be, train ja, limit 7500
# Missing: test be, train ja, limit 10000
# Missing: test be, train ga, limit 5000
# Missing: test be, train ga, limit 7500
# Missing: test be, train ga, limit 10000
# Missing: test be, train cy, limit 2500
# Missing: test be, train cy, limit 5000
# Missing: test be, train cy, limit 7500
# Missing: test be, train cy, limit 10000
# Missing: test cs, train id, limit 5000
# Missing: test cs, train id, limit 7500
# Missing: test cs, train id, limit 10000
# Missing: test cs, train lt, limit 5000
# Missing: test cs, train lt, limit 7500
# Missing: test cs, train lt, limit 10000
# Missing: test cs, train slk, limit 10000
# Missing: test cs, train uk, limit 7500
# Missing: test cs, train uk, limit 10000
# Missing: test cs, train zh, limit 5000
# Missing: test cs, train zh, limit 7500
# Missing: test cs, train zh, limit 10000
# Missing: test cs, train ar, limit 7500
# Missing: test cs, train ar, limit 10000
# Missing: test cs, train bg, limit 10000
# Missing: test cs, train hy, limit 2500
# Missing: test cs, train hy, limit 5000
# Missing: test cs, train hy, limit 7500
# Missing: test cs, train hy, limit 10000
# Missing: test cs, train fa, limit 1000
# Missing: test cs, train ja, limit 7500
# Missing: test cs, train ja, limit 10000
# Missing: test cs, train ga, limit 5000
# Missing: test cs, train ga, limit 7500
# Missing: test cs, train ga, limit 10000
# Missing: test cs, train cy, limit 2500
# Missing: test cs, train cy, limit 5000
# Missing: test cs, train cy, limit 7500
# Missing: test cs, train cy, limit 10000
# Missing: test de, train id, limit 5000
# Missing: test de, train id, limit 7500
# Missing: test de, train id, limit 10000
# Missing: test de, train lt, limit 2500
# Missing: test de, train lt, limit 5000
# Missing: test de, train lt, limit 7500
# Missing: test de, train lt, limit 10000
# Missing: test de, train slk, limit 10000
# Missing: test de, train uk, limit 7500
# Missing: test de, train uk, limit 10000
# Missing: test de, train zh, limit 5000
# Missing: test de, train zh, limit 7500
# Missing: test de, train zh, limit 10000
# Missing: test de, train ar, limit 7500
# Missing: test de, train ar, limit 10000
# Missing: test de, train bg, limit 10000
# Missing: test de, train hy, limit 2500
# Missing: test de, train hy, limit 5000
# Missing: test de, train hy, limit 7500
# Missing: test de, train hy, limit 10000
# Missing: test de, train fa, limit 1000
# Missing: test de, train ja, limit 7500
# Missing: test de, train ja, limit 10000
# Missing: test de, train ga, limit 5000
# Missing: test de, train ga, limit 7500
# Missing: test de, train ga, limit 10000
# Missing: test de, train cy, limit 2500
# Missing: test de, train cy, limit 5000
# Missing: test de, train cy, limit 7500
# Missing: test de, train cy, limit 10000
# Missing: test en, train id, limit 5000
# Missing: test en, train id, limit 7500
# Missing: test en, train id, limit 10000
# Missing: test en, train lt, limit 2500
# Missing: test en, train lt, limit 5000
# Missing: test en, train lt, limit 7500
# Missing: test en, train lt, limit 10000
# Missing: test en, train slk, limit 10000
# Missing: test en, train uk, limit 7500
# Missing: test en, train uk, limit 10000
# Missing: test en, train zh, limit 5000
# Missing: test en, train zh, limit 7500
# Missing: test en, train zh, limit 10000
# Missing: test en, train ar, limit 7500
# Missing: test en, train ar, limit 10000
# Missing: test en, train bg, limit 10000
# Missing: test en, train hy, limit 2500
# Missing: test en, train hy, limit 5000
# Missing: test en, train hy, limit 7500
# Missing: test en, train hy, limit 10000
# Missing: test en, train fa, limit 1000
# Missing: test en, train ja, limit 7500
# Missing: test en, train ja, limit 10000
# Missing: test en, train ga, limit 5000
# Missing: test en, train ga, limit 7500
# Missing: test en, train ga, limit 10000
# Missing: test en, train cy, limit 2500
# Missing: test en, train cy, limit 5000
# Missing: test en, train cy, limit 7500
# Missing: test en, train cy, limit 10000
# Missing: test es, train be, limit 1000
# Missing: test es, train be, limit 2500
# Missing: test es, train be, limit 5000
# Missing: test es, train be, limit 7500
# Missing: test es, train be, limit 10000
# Missing: test es, train cs, limit 1000
# Missing: test es, train cs, limit 2500
# Missing: test es, train cs, limit 5000
# Missing: test es, train cs, limit 7500
# Missing: test es, train cs, limit 10000
# Missing: test es, train de, limit 1000
# Missing: test es, train de, limit 2500
# Missing: test es, train de, limit 5000
# Missing: test es, train de, limit 7500
# Missing: test es, train de, limit 10000
# Missing: test es, train en, limit 1000
# Missing: test es, train en, limit 2500
# Missing: test es, train en, limit 5000
# Missing: test es, train en, limit 7500
# Missing: test es, train en, limit 10000
# Missing: test es, train es, limit 1000
# Missing: test es, train es, limit 2500
# Missing: test es, train es, limit 5000
# Missing: test es, train es, limit 7500
# Missing: test es, train es, limit 10000
# Missing: test es, train fi, limit 1000
# Missing: test es, train fi, limit 2500
# Missing: test es, train fi, limit 5000
# Missing: test es, train fi, limit 7500
# Missing: test es, train fi, limit 10000
# Missing: test es, train fr, limit 1000
# Missing: test es, train fr, limit 2500
# Missing: test es, train fr, limit 5000
# Missing: test es, train fr, limit 7500
# Missing: test es, train fr, limit 10000
# Missing: test es, train id, limit 1000
# Missing: test es, train id, limit 2500
# Missing: test es, train id, limit 5000
# Missing: test es, train id, limit 7500
# Missing: test es, train id, limit 10000
# Missing: test es, train lv, limit 1000
# Missing: test es, train lv, limit 2500
# Missing: test es, train lv, limit 5000
# Missing: test es, train lv, limit 7500
# Missing: test es, train lv, limit 10000
# Missing: test es, train lt, limit 1000
# Missing: test es, train lt, limit 2500
# Missing: test es, train lt, limit 5000
# Missing: test es, train lt, limit 7500
# Missing: test es, train lt, limit 10000
# Missing: test es, train slk, limit 10000
# Missing: test es, train uk, limit 7500
# Missing: test es, train uk, limit 10000
# Missing: test es, train zh, limit 5000
# Missing: test es, train zh, limit 7500
# Missing: test es, train zh, limit 10000
# Missing: test es, train ar, limit 1000
# Missing: test es, train ar, limit 2500
# Missing: test es, train ar, limit 5000
# Missing: test es, train ar, limit 7500
# Missing: test es, train ar, limit 10000
# Missing: test es, train bg, limit 1000
# Missing: test es, train bg, limit 2500
# Missing: test es, train bg, limit 5000
# Missing: test es, train bg, limit 7500
# Missing: test es, train bg, limit 10000
# Missing: test es, train tr, limit 1000
# Missing: test es, train tr, limit 2500
# Missing: test es, train tr, limit 5000
# Missing: test es, train tr, limit 7500
# Missing: test es, train tr, limit 10000
# Missing: test es, train ko, limit 1000
# Missing: test es, train ko, limit 2500
# Missing: test es, train ko, limit 5000
# Missing: test es, train ko, limit 7500
# Missing: test es, train ko, limit 10000
# Missing: test es, train hy, limit 1000
# Missing: test es, train hy, limit 2500
# Missing: test es, train hy, limit 5000
# Missing: test es, train hy, limit 7500
# Missing: test es, train hy, limit 10000
# Missing: test es, train fa, limit 1000
# Missing: test es, train fa, limit 2500
# Missing: test es, train fa, limit 5000
# Missing: test es, train fa, limit 7500
# Missing: test es, train fa, limit 10000
# Missing: test es, train ja, limit 1000
# Missing: test es, train ja, limit 2500
# Missing: test es, train ja, limit 5000
# Missing: test es, train ja, limit 7500
# Missing: test es, train ja, limit 10000
# Missing: test es, train ga, limit 1000
# Missing: test es, train ga, limit 2500
# Missing: test es, train ga, limit 5000
# Missing: test es, train ga, limit 7500
# Missing: test es, train ga, limit 10000
# Missing: test es, train cy, limit 1000
# Missing: test es, train cy, limit 2500
# Missing: test es, train cy, limit 5000
# Missing: test es, train cy, limit 7500
# Missing: test es, train cy, limit 10000
# Missing: test fi, train id, limit 5000
# Missing: test fi, train id, limit 7500
# Missing: test fi, train id, limit 10000
# Missing: test fi, train lt, limit 2500
# Missing: test fi, train lt, limit 5000
# Missing: test fi, train lt, limit 7500
# Missing: test fi, train lt, limit 10000
# Missing: test fi, train slk, limit 10000
# Missing: test fi, train uk, limit 7500
# Missing: test fi, train uk, limit 10000
# Missing: test fi, train zh, limit 5000
# Missing: test fi, train zh, limit 7500
# Missing: test fi, train zh, limit 10000
# Missing: test fi, train ar, limit 7500
# Missing: test fi, train ar, limit 10000
# Missing: test fi, train bg, limit 10000
# Missing: test fi, train hy, limit 2500
# Missing: test fi, train hy, limit 5000
# Missing: test fi, train hy, limit 7500
# Missing: test fi, train hy, limit 10000
# Missing: test fi, train fa, limit 1000
# Missing: test fi, train ja, limit 7500
# Missing: test fi, train ja, limit 10000
# Missing: test fi, train ga, limit 5000
# Missing: test fi, train ga, limit 7500
# Missing: test fi, train ga, limit 10000
# Missing: test fi, train cy, limit 2500
# Missing: test fi, train cy, limit 5000
# Missing: test fi, train cy, limit 7500
# Missing: test fi, train cy, limit 10000
# Missing: test fr, train id, limit 5000
# Missing: test fr, train id, limit 7500
# Missing: test fr, train id, limit 10000
# Missing: test fr, train lt, limit 2500
# Missing: test fr, train lt, limit 5000
# Missing: test fr, train lt, limit 7500
# Missing: test fr, train lt, limit 10000
# Missing: test fr, train slk, limit 10000
# Missing: test fr, train uk, limit 7500
# Missing: test fr, train uk, limit 10000
# Missing: test fr, train zh, limit 5000
# Missing: test fr, train zh, limit 7500
# Missing: test fr, train zh, limit 10000
# Missing: test fr, train ar, limit 7500
# Missing: test fr, train ar, limit 10000
# Missing: test fr, train bg, limit 10000
# Missing: test fr, train hy, limit 2500
# Missing: test fr, train hy, limit 5000
# Missing: test fr, train hy, limit 7500
# Missing: test fr, train hy, limit 10000
# Missing: test fr, train fa, limit 1000
# Missing: test fr, train ja, limit 7500
# Missing: test fr, train ja, limit 10000
# Missing: test fr, train ga, limit 5000
# Missing: test fr, train ga, limit 7500
# Missing: test fr, train ga, limit 10000
# Missing: test fr, train cy, limit 2500
# Missing: test fr, train cy, limit 5000
# Missing: test fr, train cy, limit 7500
# Missing: test fr, train cy, limit 10000
# Missing: test id, train id, limit 5000
# Missing: test id, train id, limit 7500
# Missing: test id, train id, limit 10000
# Missing: test id, train lt, limit 2500
# Missing: test id, train lt, limit 5000
# Missing: test id, train lt, limit 7500
# Missing: test id, train lt, limit 10000
# Missing: test id, train slk, limit 10000
# Missing: test id, train uk, limit 7500
# Missing: test id, train uk, limit 10000
# Missing: test id, train zh, limit 5000
# Missing: test id, train zh, limit 7500
# Missing: test id, train zh, limit 10000
# Missing: test id, train ar, limit 7500
# Missing: test id, train ar, limit 10000
# Missing: test id, train bg, limit 10000
# Missing: test id, train hy, limit 2500
# Missing: test id, train hy, limit 5000
# Missing: test id, train hy, limit 7500
# Missing: test id, train hy, limit 10000
# Missing: test id, train fa, limit 1000
# Missing: test id, train ja, limit 7500
# Missing: test id, train ja, limit 10000
# Missing: test id, train ga, limit 5000
# Missing: test id, train ga, limit 7500
# Missing: test id, train ga, limit 10000
# Missing: test id, train cy, limit 2500
# Missing: test id, train cy, limit 5000
# Missing: test id, train cy, limit 7500
# Missing: test id, train cy, limit 10000
# Missing: test lv, train id, limit 5000
# Missing: test lv, train id, limit 7500
# Missing: test lv, train id, limit 10000
# Missing: test lv, train lt, limit 2500
# Missing: test lv, train lt, limit 5000
# Missing: test lv, train lt, limit 7500
# Missing: test lv, train lt, limit 10000
# Missing: test lv, train slk, limit 10000
# Missing: test lv, train uk, limit 7500
# Missing: test lv, train uk, limit 10000
# Missing: test lv, train zh, limit 5000
# Missing: test lv, train zh, limit 7500
# Missing: test lv, train zh, limit 10000
# Missing: test lv, train ar, limit 7500
# Missing: test lv, train ar, limit 10000
# Missing: test lv, train bg, limit 10000
# Missing: test lv, train hy, limit 2500
# Missing: test lv, train hy, limit 5000
# Missing: test lv, train hy, limit 7500
# Missing: test lv, train hy, limit 10000
# Missing: test lv, train fa, limit 1000
# Missing: test lv, train ja, limit 7500
# Missing: test lv, train ja, limit 10000
# Missing: test lv, train ga, limit 5000
# Missing: test lv, train ga, limit 7500
# Missing: test lv, train ga, limit 10000
# Missing: test lv, train cy, limit 2500
# Missing: test lv, train cy, limit 5000
# Missing: test lv, train cy, limit 7500
# Missing: test lv, train cy, limit 10000
# Missing: test lt, train id, limit 5000
# Missing: test lt, train id, limit 7500
# Missing: test lt, train id, limit 10000
# Missing: test lt, train lt, limit 2500
# Missing: test lt, train lt, limit 5000
# Missing: test lt, train lt, limit 7500
# Missing: test lt, train lt, limit 10000
# Missing: test lt, train slk, limit 10000
# Missing: test lt, train uk, limit 7500
# Missing: test lt, train uk, limit 10000
# Missing: test lt, train zh, limit 5000
# Missing: test lt, train zh, limit 7500
# Missing: test lt, train zh, limit 10000
# Missing: test lt, train ar, limit 7500
# Missing: test lt, train ar, limit 10000
# Missing: test lt, train bg, limit 10000
# Missing: test lt, train hy, limit 2500
# Missing: test lt, train hy, limit 5000
# Missing: test lt, train hy, limit 7500
# Missing: test lt, train hy, limit 10000
# Missing: test lt, train fa, limit 1000
# Missing: test lt, train ja, limit 7500
# Missing: test lt, train ja, limit 10000
# Missing: test lt, train ga, limit 5000
# Missing: test lt, train ga, limit 7500
# Missing: test lt, train ga, limit 10000
# Missing: test lt, train cy, limit 2500
# Missing: test lt, train cy, limit 5000
# Missing: test lt, train cy, limit 7500
# Missing: test lt, train cy, limit 10000
# Missing: test pl, train id, limit 5000
# Missing: test pl, train id, limit 7500
# Missing: test pl, train id, limit 10000
# Missing: test pl, train lt, limit 5000
# Missing: test pl, train lt, limit 7500
# Missing: test pl, train lt, limit 10000
# Missing: test pl, train slk, limit 10000
# Missing: test pl, train uk, limit 7500
# Missing: test pl, train uk, limit 10000
# Missing: test pl, train zh, limit 5000
# Missing: test pl, train zh, limit 7500
# Missing: test pl, train zh, limit 10000
# Missing: test pl, train ar, limit 7500
# Missing: test pl, train ar, limit 10000
# Missing: test pl, train bg, limit 10000
# Missing: test pl, train hy, limit 2500
# Missing: test pl, train hy, limit 5000
# Missing: test pl, train hy, limit 7500
# Missing: test pl, train hy, limit 10000
# Missing: test pl, train fa, limit 1000
# Missing: test pl, train ja, limit 7500
# Missing: test pl, train ja, limit 10000
# Missing: test pl, train ga, limit 5000
# Missing: test pl, train ga, limit 7500
# Missing: test pl, train ga, limit 10000
# Missing: test pl, train cy, limit 2500
# Missing: test pl, train cy, limit 5000
# Missing: test pl, train cy, limit 7500
# Missing: test pl, train cy, limit 10000
# Missing: test ru, train id, limit 5000
# Missing: test ru, train id, limit 7500
# Missing: test ru, train id, limit 10000
# Missing: test ru, train lt, limit 5000
# Missing: test ru, train lt, limit 7500
# Missing: test ru, train lt, limit 10000
# Missing: test ru, train slk, limit 10000
# Missing: test ru, train uk, limit 7500
# Missing: test ru, train uk, limit 10000
# Missing: test ru, train zh, limit 5000
# Missing: test ru, train zh, limit 7500
# Missing: test ru, train zh, limit 10000
# Missing: test ru, train ar, limit 7500
# Missing: test ru, train ar, limit 10000
# Missing: test ru, train bg, limit 10000
# Missing: test ru, train hy, limit 2500
# Missing: test ru, train hy, limit 5000
# Missing: test ru, train hy, limit 7500
# Missing: test ru, train hy, limit 10000
# Missing: test ru, train fa, limit 1000
# Missing: test ru, train ja, limit 7500
# Missing: test ru, train ja, limit 10000
# Missing: test ru, train ga, limit 5000
# Missing: test ru, train ga, limit 7500
# Missing: test ru, train ga, limit 10000
# Missing: test ru, train cy, limit 2500
# Missing: test ru, train cy, limit 5000
# Missing: test ru, train cy, limit 7500
# Missing: test ru, train cy, limit 10000
# Missing: test slk, train id, limit 5000
# Missing: test slk, train id, limit 7500
# Missing: test slk, train id, limit 10000
# Missing: test slk, train lt, limit 5000
# Missing: test slk, train lt, limit 7500
# Missing: test slk, train lt, limit 10000
# Missing: test slk, train slk, limit 10000
# Missing: test slk, train uk, limit 7500
# Missing: test slk, train uk, limit 10000
# Missing: test slk, train zh, limit 5000
# Missing: test slk, train zh, limit 7500
# Missing: test slk, train zh, limit 10000
# Missing: test slk, train ar, limit 7500
# Missing: test slk, train ar, limit 10000
# Missing: test slk, train bg, limit 10000
# Missing: test slk, train hy, limit 2500
# Missing: test slk, train hy, limit 5000
# Missing: test slk, train hy, limit 7500
# Missing: test slk, train hy, limit 10000
# Missing: test slk, train fa, limit 1000
# Missing: test slk, train ja, limit 7500
# Missing: test slk, train ja, limit 10000
# Missing: test slk, train ga, limit 5000
# Missing: test slk, train ga, limit 7500
# Missing: test slk, train ga, limit 10000
# Missing: test slk, train cy, limit 2500
# Missing: test slk, train cy, limit 5000
# Missing: test slk, train cy, limit 7500
# Missing: test slk, train cy, limit 10000
# Missing: test slv, train id, limit 5000
# Missing: test slv, train id, limit 7500
# Missing: test slv, train id, limit 10000
# Missing: test slv, train lt, limit 5000
# Missing: test slv, train lt, limit 7500
# Missing: test slv, train lt, limit 10000
# Missing: test slv, train slk, limit 10000
# Missing: test slv, train uk, limit 7500
# Missing: test slv, train uk, limit 10000
# Missing: test slv, train zh, limit 5000
# Missing: test slv, train zh, limit 7500
# Missing: test slv, train zh, limit 10000
# Missing: test slv, train ar, limit 7500
# Missing: test slv, train ar, limit 10000
# Missing: test slv, train bg, limit 10000
# Missing: test slv, train hy, limit 2500
# Missing: test slv, train hy, limit 5000
# Missing: test slv, train hy, limit 7500
# Missing: test slv, train hy, limit 10000
# Missing: test slv, train fa, limit 1000
# Missing: test slv, train ja, limit 7500
# Missing: test slv, train ja, limit 10000
# Missing: test slv, train ga, limit 5000
# Missing: test slv, train ga, limit 7500
# Missing: test slv, train ga, limit 10000
# Missing: test slv, train cy, limit 2500
# Missing: test slv, train cy, limit 5000
# Missing: test slv, train cy, limit 7500
# Missing: test slv, train cy, limit 10000
# Missing: test uk, train id, limit 5000
# Missing: test uk, train id, limit 7500
# Missing: test uk, train id, limit 10000
# Missing: test uk, train lt, limit 5000
# Missing: test uk, train lt, limit 7500
# Missing: test uk, train lt, limit 10000
# Missing: test uk, train slk, limit 10000
# Missing: test uk, train uk, limit 7500
# Missing: test uk, train uk, limit 10000
# Missing: test uk, train zh, limit 5000
# Missing: test uk, train zh, limit 7500
# Missing: test uk, train zh, limit 10000
# Missing: test uk, train ar, limit 7500
# Missing: test uk, train ar, limit 10000
# Missing: test uk, train bg, limit 10000
# Missing: test uk, train hy, limit 2500
# Missing: test uk, train hy, limit 5000
# Missing: test uk, train hy, limit 7500
# Missing: test uk, train hy, limit 10000
# Missing: test uk, train fa, limit 1000
# Missing: test uk, train ja, limit 7500
# Missing: test uk, train ja, limit 10000
# Missing: test uk, train ga, limit 5000
# Missing: test uk, train ga, limit 7500
# Missing: test uk, train ga, limit 10000
# Missing: test uk, train cy, limit 2500
# Missing: test uk, train cy, limit 5000
# Missing: test uk, train cy, limit 7500
# Missing: test uk, train cy, limit 10000
# Missing: test zh, train id, limit 5000
# Missing: test zh, train id, limit 7500
# Missing: test zh, train id, limit 10000
# Missing: test zh, train lt, limit 2500
# Missing: test zh, train lt, limit 5000
# Missing: test zh, train lt, limit 7500
# Missing: test zh, train lt, limit 10000
# Missing: test zh, train slk, limit 10000
# Missing: test zh, train uk, limit 7500
# Missing: test zh, train uk, limit 10000
# Missing: test zh, train zh, limit 5000
# Missing: test zh, train zh, limit 7500
# Missing: test zh, train zh, limit 10000
# Missing: test zh, train ar, limit 7500
# Missing: test zh, train ar, limit 10000
# Missing: test zh, train bg, limit 10000
# Missing: test zh, train hy, limit 2500
# Missing: test zh, train hy, limit 5000
# Missing: test zh, train hy, limit 7500
# Missing: test zh, train hy, limit 10000
# Missing: test zh, train fa, limit 1000
# Missing: test zh, train ja, limit 7500
# Missing: test zh, train ja, limit 10000
# Missing: test zh, train ga, limit 5000
# Missing: test zh, train ga, limit 7500
# Missing: test zh, train ga, limit 10000
# Missing: test zh, train cy, limit 2500
# Missing: test zh, train cy, limit 5000
# Missing: test zh, train cy, limit 7500
# Missing: test zh, train cy, limit 10000
# Missing: test ar, train id, limit 5000
# Missing: test ar, train id, limit 7500
# Missing: test ar, train id, limit 10000
# Missing: test ar, train lt, limit 2500
# Missing: test ar, train lt, limit 5000
# Missing: test ar, train lt, limit 7500
# Missing: test ar, train lt, limit 10000
# Missing: test ar, train slk, limit 10000
# Missing: test ar, train uk, limit 7500
# Missing: test ar, train uk, limit 10000
# Missing: test ar, train zh, limit 5000
# Missing: test ar, train zh, limit 7500
# Missing: test ar, train zh, limit 10000
# Missing: test ar, train ar, limit 7500
# Missing: test ar, train ar, limit 10000
# Missing: test ar, train bg, limit 10000
# Missing: test ar, train hy, limit 2500
# Missing: test ar, train hy, limit 5000
# Missing: test ar, train hy, limit 7500
# Missing: test ar, train hy, limit 10000
# Missing: test ar, train fa, limit 1000
# Missing: test ar, train ja, limit 7500
# Missing: test ar, train ja, limit 10000
# Missing: test ar, train ga, limit 5000
# Missing: test ar, train ga, limit 7500
# Missing: test ar, train ga, limit 10000
# Missing: test ar, train cy, limit 2500
# Missing: test ar, train cy, limit 5000
# Missing: test ar, train cy, limit 7500
# Missing: test ar, train cy, limit 10000
# Missing: test bg, train id, limit 5000
# Missing: test bg, train id, limit 7500
# Missing: test bg, train id, limit 10000
# Missing: test bg, train lt, limit 2500
# Missing: test bg, train lt, limit 5000
# Missing: test bg, train lt, limit 7500
# Missing: test bg, train lt, limit 10000
# Missing: test bg, train slk, limit 10000
# Missing: test bg, train uk, limit 7500
# Missing: test bg, train uk, limit 10000
# Missing: test bg, train zh, limit 5000
# Missing: test bg, train zh, limit 7500
# Missing: test bg, train zh, limit 10000
# Missing: test bg, train ar, limit 7500
# Missing: test bg, train ar, limit 10000
# Missing: test bg, train bg, limit 10000
# Missing: test bg, train hy, limit 2500
# Missing: test bg, train hy, limit 5000
# Missing: test bg, train hy, limit 7500
# Missing: test bg, train hy, limit 10000
# Missing: test bg, train fa, limit 1000
# Missing: test bg, train ja, limit 7500
# Missing: test bg, train ja, limit 10000
# Missing: test bg, train ga, limit 5000
# Missing: test bg, train ga, limit 7500
# Missing: test bg, train ga, limit 10000
# Missing: test bg, train cy, limit 2500
# Missing: test bg, train cy, limit 5000
# Missing: test bg, train cy, limit 7500
# Missing: test bg, train cy, limit 10000
# Missing: test tr, train id, limit 5000
# Missing: test tr, train id, limit 7500
# Missing: test tr, train id, limit 10000
# Missing: test tr, train lt, limit 2500
# Missing: test tr, train lt, limit 5000
# Missing: test tr, train lt, limit 7500
# Missing: test tr, train lt, limit 10000
# Missing: test tr, train slk, limit 10000
# Missing: test tr, train uk, limit 7500
# Missing: test tr, train uk, limit 10000
# Missing: test tr, train zh, limit 5000
# Missing: test tr, train zh, limit 7500
# Missing: test tr, train zh, limit 10000
# Missing: test tr, train ar, limit 7500
# Missing: test tr, train ar, limit 10000
# Missing: test tr, train bg, limit 10000
# Missing: test tr, train hy, limit 2500
# Missing: test tr, train hy, limit 5000
# Missing: test tr, train hy, limit 7500
# Missing: test tr, train hy, limit 10000
# Missing: test tr, train fa, limit 1000
# Missing: test tr, train ja, limit 7500
# Missing: test tr, train ja, limit 10000
# Missing: test tr, train ga, limit 5000
# Missing: test tr, train ga, limit 7500
# Missing: test tr, train ga, limit 10000
# Missing: test tr, train cy, limit 2500
# Missing: test tr, train cy, limit 5000
# Missing: test tr, train cy, limit 7500
# Missing: test tr, train cy, limit 10000
# Missing: test ko, train id, limit 5000
# Missing: test ko, train id, limit 7500
# Missing: test ko, train id, limit 10000
# Missing: test ko, train lt, limit 2500
# Missing: test ko, train lt, limit 5000
# Missing: test ko, train lt, limit 7500
# Missing: test ko, train lt, limit 10000
# Missing: test ko, train slk, limit 10000
# Missing: test ko, train uk, limit 7500
# Missing: test ko, train uk, limit 10000
# Missing: test ko, train zh, limit 5000
# Missing: test ko, train zh, limit 7500
# Missing: test ko, train zh, limit 10000
# Missing: test ko, train ar, limit 7500
# Missing: test ko, train ar, limit 10000
# Missing: test ko, train bg, limit 10000
# Missing: test ko, train hy, limit 2500
# Missing: test ko, train hy, limit 5000
# Missing: test ko, train hy, limit 7500
# Missing: test ko, train hy, limit 10000
# Missing: test ko, train fa, limit 1000
# Missing: test ko, train ja, limit 7500
# Missing: test ko, train ja, limit 10000
# Missing: test ko, train ga, limit 5000
# Missing: test ko, train ga, limit 7500
# Missing: test ko, train ga, limit 10000
# Missing: test ko, train cy, limit 2500
# Missing: test ko, train cy, limit 5000
# Missing: test ko, train cy, limit 7500
# Missing: test ko, train cy, limit 10000
# Missing: test hy, train id, limit 5000
# Missing: test hy, train id, limit 7500
# Missing: test hy, train id, limit 10000
# Missing: test hy, train lt, limit 2500
# Missing: test hy, train lt, limit 5000
# Missing: test hy, train lt, limit 7500
# Missing: test hy, train lt, limit 10000
# Missing: test hy, train slk, limit 10000
# Missing: test hy, train uk, limit 7500
# Missing: test hy, train uk, limit 10000
# Missing: test hy, train zh, limit 5000
# Missing: test hy, train zh, limit 7500
# Missing: test hy, train zh, limit 10000
# Missing: test hy, train ar, limit 7500
# Missing: test hy, train ar, limit 10000
# Missing: test hy, train bg, limit 10000
# Missing: test hy, train hy, limit 2500
# Missing: test hy, train hy, limit 5000
# Missing: test hy, train hy, limit 7500
# Missing: test hy, train hy, limit 10000
# Missing: test hy, train fa, limit 1000
# Missing: test hy, train ja, limit 7500
# Missing: test hy, train ja, limit 10000
# Missing: test hy, train ga, limit 5000
# Missing: test hy, train ga, limit 7500
# Missing: test hy, train ga, limit 10000
# Missing: test hy, train cy, limit 2500
# Missing: test hy, train cy, limit 5000
# Missing: test hy, train cy, limit 7500
# Missing: test hy, train cy, limit 10000
# Missing: test fa, train id, limit 5000
# Missing: test fa, train id, limit 7500
# Missing: test fa, train id, limit 10000
# Missing: test fa, train lt, limit 2500
# Missing: test fa, train lt, limit 5000
# Missing: test fa, train lt, limit 7500
# Missing: test fa, train lt, limit 10000
# Missing: test fa, train slk, limit 10000
# Missing: test fa, train uk, limit 7500
# Missing: test fa, train uk, limit 10000
# Missing: test fa, train zh, limit 5000
# Missing: test fa, train zh, limit 7500
# Missing: test fa, train zh, limit 10000
# Missing: test fa, train ar, limit 7500
# Missing: test fa, train ar, limit 10000
# Missing: test fa, train bg, limit 10000
# Missing: test fa, train hy, limit 2500
# Missing: test fa, train hy, limit 5000
# Missing: test fa, train hy, limit 7500
# Missing: test fa, train hy, limit 10000
# Missing: test fa, train fa, limit 1000
# Missing: test fa, train ja, limit 7500
# Missing: test fa, train ja, limit 10000
# Missing: test fa, train ga, limit 5000
# Missing: test fa, train ga, limit 7500
# Missing: test fa, train ga, limit 10000
# Missing: test fa, train cy, limit 2500
# Missing: test fa, train cy, limit 5000
# Missing: test fa, train cy, limit 7500
# Missing: test fa, train cy, limit 10000
# Missing: test ja, train id, limit 5000
# Missing: test ja, train id, limit 7500
# Missing: test ja, train id, limit 10000
# Missing: test ja, train lt, limit 2500
# Missing: test ja, train lt, limit 5000
# Missing: test ja, train lt, limit 7500
# Missing: test ja, train lt, limit 10000
# Missing: test ja, train slk, limit 10000
# Missing: test ja, train uk, limit 7500
# Missing: test ja, train uk, limit 10000
# Missing: test ja, train zh, limit 5000
# Missing: test ja, train zh, limit 7500
# Missing: test ja, train zh, limit 10000
# Missing: test ja, train ar, limit 7500
# Missing: test ja, train ar, limit 10000
# Missing: test ja, train bg, limit 10000
# Missing: test ja, train hy, limit 2500
# Missing: test ja, train hy, limit 5000
# Missing: test ja, train hy, limit 7500
# Missing: test ja, train hy, limit 10000
# Missing: test ja, train fa, limit 1000
# Missing: test ja, train ja, limit 7500
# Missing: test ja, train ja, limit 10000
# Missing: test ja, train ga, limit 5000
# Missing: test ja, train ga, limit 7500
# Missing: test ja, train ga, limit 10000
# Missing: test ja, train cy, limit 2500
# Missing: test ja, train cy, limit 5000
# Missing: test ja, train cy, limit 7500
# Missing: test ja, train cy, limit 10000
# Missing: test ga, train id, limit 5000
# Missing: test ga, train id, limit 7500
# Missing: test ga, train id, limit 10000
# Missing: test ga, train lt, limit 2500
# Missing: test ga, train lt, limit 5000
# Missing: test ga, train lt, limit 7500
# Missing: test ga, train lt, limit 10000
# Missing: test ga, train slk, limit 10000
# Missing: test ga, train uk, limit 7500
# Missing: test ga, train uk, limit 10000
# Missing: test ga, train zh, limit 5000
# Missing: test ga, train zh, limit 7500
# Missing: test ga, train zh, limit 10000
# Missing: test ga, train ar, limit 7500
# Missing: test ga, train ar, limit 10000
# Missing: test ga, train bg, limit 10000
# Missing: test ga, train hy, limit 2500
# Missing: test ga, train hy, limit 5000
# Missing: test ga, train hy, limit 7500
# Missing: test ga, train hy, limit 10000
# Missing: test ga, train fa, limit 1000
# Missing: test ga, train ja, limit 7500
# Missing: test ga, train ja, limit 10000
# Missing: test ga, train ga, limit 5000
# Missing: test ga, train ga, limit 7500
# Missing: test ga, train ga, limit 10000
# Missing: test ga, train cy, limit 2500
# Missing: test ga, train cy, limit 5000
# Missing: test ga, train cy, limit 7500
# Missing: test ga, train cy, limit 10000
# Missing: test cy, train id, limit 5000
# Missing: test cy, train id, limit 7500
# Missing: test cy, train id, limit 10000
# Missing: test cy, train lt, limit 2500
# Missing: test cy, train lt, limit 5000
# Missing: test cy, train lt, limit 7500
# Missing: test cy, train lt, limit 10000
# Missing: test cy, train slk, limit 10000
# Missing: test cy, train uk, limit 7500
# Missing: test cy, train uk, limit 10000
# Missing: test cy, train zh, limit 5000
# Missing: test cy, train zh, limit 7500
# Missing: test cy, train zh, limit 10000
# Missing: test cy, train ar, limit 7500
# Missing: test cy, train ar, limit 10000
# Missing: test cy, train bg, limit 10000
# Missing: test cy, train hy, limit 2500
# Missing: test cy, train hy, limit 5000
# Missing: test cy, train hy, limit 7500
# Missing: test cy, train hy, limit 10000
# Missing: test cy, train fa, limit 1000
# Missing: test cy, train ja, limit 7500
# Missing: test cy, train ja, limit 10000
# Missing: test cy, train ga, limit 5000
# Missing: test cy, train ga, limit 7500
# Missing: test cy, train ga, limit 10000
# Missing: test cy, train cy, limit 2500
# Missing: test cy, train cy, limit 5000
# Missing: test cy, train cy, limit 7500
# Missing: test cy, train cy, limit 10000

# %%
print(f"Missing {counter} exps of {len(set(product(LANGS, LANGS, LIMITS)))}")
# Out:
# Missing 814 exps of 3125

# %%
for filename in os.listdir('multilingual-probing-visualization/configs/all_new'): # skip the Nones for now? and 100s?
    ttl = filename[:-5]
    test, train, limit = ttl.split('_')
    if (test, train, limit) in missing:
        missing.remove((test, train, limit))
        if limit not in (None, 100):
            src_path = os.path.join('multilingual-probing-visualization/configs/all_new', filename)
            dest_path = src_path.replace('all_new', 'missing_new')
            os.rename(src_path, dest_path)

# %%
print(missing)
# Out:
# {('fi', 'zh', '7500'), ('cs', 'ga', '10000'), ('de', 'cy', '7500'), ('fi', 'lt', '10000'), ('fr', 'cy', '5000'), ('lv', 'lt', '10000'), ('tr', 'hy', '7500'), ('ko', 'hy', '10000'), ('id', 'uk', '7500'), ('pl', 'ga', '7500'), ('hy', 'uk', '7500'), ('zh', 'cy', '7500'), ('lt', 'lt', '5000'), ('lt', 'hy', '10000'), ('es', 'zh', '7500'), ('slv', 'cy', '5000'), ('hy', 'slk', '10000'), ('cy', 'ar', '7500'), ('slv', 'hy', '2500'), ('id', 'lt', '7500'), ('lt', 'lt', '7500'), ('cy', 'ga', '5000'), ('slv', 'cy', '7500'), ('uk', 'id', '10000'), ('ko', 'hy', '7500'), ('cs', 'zh', '10000'), ('bg', 'lt', '5000'), ('fa', 'lt', '5000'), ('en', 'bg', '10000'), ('en', 'ar', '10000'), ('zh', 'ga', '10000'), ('ko', 'lt', '5000'), ('cs', 'hy', '10000'), ('ru', 'hy', '10000'), ('slv', 'zh', '5000'), ('slk', 'ja', '10000'), ('fa', 'uk', '7500'), ('es', 'uk', '10000'), ('bg', 'lt', '7500'), ('fa', 'lt', '7500'), ('fa', 'hy', '10000'), ('de', 'hy', '2500'), ('cy', 'zh', '5000'), ('en', 'id', '5000'), ('zh', 'ga', '5000'), ('cs', 'hy', '5000'), ('zh', 'hy', '2500'), ('slv', 'zh', '7500'), ('lt', 'uk', '7500'), ('slv', 'ga', '10000'), ('ar', 'ja', '7500'), ('tr', 'cy', '2500'), ('fr', 'ga', '5000'), ('ga', 'cy', '2500'), ('de', 'zh', '10000'), ('id', 'slk', '10000'), ('bg', 'cy', '2500'), ('en', 'id', '7500'), ('zh', 'ga', '7500'), ('cs', 'hy', '7500'), ('zh', 'zh', '10000'), ('ru', 'hy', '7500'), ('ga', 'bg', '10000'), ('slv', 'ga', '5000'), ('ga', 'ar', '10000'), ('fi', 'slk', '10000'), ('lv', 'slk', '10000'), ('slk', 'ja', '7500'), ('de', 'zh', '5000'), ('fr', 'ga', '7500'), ('bg', 'ar', '10000'), ('en', 'hy', '2500'), ('hy', 'ja', '7500'), ('zh', 'zh', '5000'), ('fi', 'ja', '7500'), ('lv', 'ja', '7500'), ('ru', 'lt', '5000'), ('slv', 'ga', '7500'), ('be', 'ga', '5000'), ('de', 'ga', '5000'), ('pl', 'ja', '10000'), ('de', 'zh', '7500'), ('fr', 'zh', '5000'), ('ar', 'cy', '10000'), ('ar', 'slk', '10000'), ('zh', 'zh', '7500'), ('en', 'cy', '10000'), ('ru', 'lt', '7500'), ('slk', 'slk', '10000'), ('de', 'ga', '7500'), ('fr', 'zh', '7500'), ('id', 'id', '10000'), ('id', 'cy', '10000'), ('en', 'cy', '5000'), ('ga', 'hy', '2500'), ('fi', 'id', '10000'), ('lv', 'id', '10000'), ('lv', 'cy', '10000'), ('tr', 'ar', '10000'), ('cs', 'cy', '2500'), ('be', 'zh', '5000'), ('pl', 'ja', '7500'), ('hy', 'lt', '2500'), ('id', 'id', '5000'), ('en', 'cy', '7500'), ('fa', 'cy', '2500'), ('cs', 'ar', '10000'), ('be', 'uk', '10000'), ('de', 'uk', '10000'), ('pl', 'ar', '7500'), ('uk', 'hy', '10000'), ('ko', 'cy', '2500'), ('bg', 'bg', '10000'), ('be', 'lt', '10000'), ('de', 'hy', '5000'), ('ar', 'id', '10000'), ('id', 'id', '7500'), ('zh', 'uk', '10000'), ('fa', 'ar', '10000'), ('es', 'slk', '10000'), ('ko', 'ar', '10000'), ('tr', 'ar', '7500'), ('ga', 'id', '5000'), ('tr', 'cy', '5000'), ('fr', 'uk', '10000'), ('ga', 'cy', '5000'), ('slk', 'id', '10000'), ('lt', 'bg', '10000'), ('bg', 'id', '5000'), ('fr', 'lt', '10000'), ('bg', 'cy', '5000'), ('ja', 'lt', '10000'), ('es', 'ja', '7500'), ('hy', 'id', '10000'), ('tr', 'hy', '2500'), ('cs', 'ar', '7500'), ('ar', 'lt', '2500'), ('tr', 'cy', '7500'), ('ga', 'cy', '7500'), ('en', 'hy', '5000'), ('ar', 'id', '7500'), ('en', 'ga', '10000'), ('cy', 'uk', '10000'), ('bg', 'cy', '7500'), ('cy', 'lt', '10000'), ('lt', 'cy', '10000'), ('tr', 'zh', '10000'), ('ko', 'ar', '7500'), ('id', 'ga', '10000'), ('zh', 'slk', '10000'), ('uk', 'lt', '5000'), ('bg', 'hy', '2500'), ('id', 'lt', '2500'), ('slv', 'ja', '10000'), ('en', 'hy', '7500'), ('lt', 'lt', '2500'), ('ru', 'cy', '2500'), ('hy', 'id', '7500'), ('tr', 'zh', '5000'), ('fi', 'lt', '2500'), ('lv', 'lt', '2500'), ('ko', 'hy', '2500'), ('ru', 'bg', '10000'), ('uk', 'uk', '7500'), ('ru', 'ar', '10000'), ('uk', 'lt', '7500'), ('ja', 'uk', '10000'), ('lt', 'hy', '2500'), ('en', 'zh', '10000'), ('slv', 'slk', '10000'), ('fa', 'bg', '10000'), ('fr', 'ja', '7500'), ('lt', 'cy', '7500'), ('tr', 'zh', '7500'), ('tr', 'ga', '10000'), ('ga', 'hy', '5000'), ('fa', 'cy', '10000'), ('ga', 'ga',  ...

# %%
len(missing)
# Out:
# 718

# %%
max_dict = {
    'ar': 6074,
    'pl': 17721,
    'bg': 8906,
    'be': 22852,
    'fr': 14448,
    'en': 12542,
    'lv': 12520,
    'fa': 4797,
    'lt': 2340,
    'cs': 68494,
    'es': 14286, 
    'zh': 3996,
    'slk': 8482,
    'slv': 10902,
    'uk': 5495,
    'ru': 69629,
    'de': 13813,
    'fi': 12216,
    'id': 4481,
    'hr': 6913,
    'tr': 14850,
    'ko': 23010,
    'hy': 1974,
    'fa': 26196,
    'ja': 7050,
    'ga': 4005,
    'cy': 1111,
}

# %%
for test, train, l in missing:
    if max_dict[train] > int(l):
        print(test, train, l) # okay, good, only a couple missing then
